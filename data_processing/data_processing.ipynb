# %%
import pandas as pd

# %%
URL_CREATE_POST = "http://localhost:8000/product"
URL_CREATE_TAG = "http://localhost:8000/category"
TOKEN = "eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJlbWFpbCI6ImFkbWluQGdtYWlsLmNvbSIsImlhdCI6MTcxNjIzMTQwMywiZXhwIjoxNzE2NDkwNjAzfQ.3rVRsQUYxv4F6-JUdJFBmhb2SD8ZBoMrAlgnbCsfLac"

# %%
data = pd.read_csv("data/data.csv")
data = data[:1000]

# %%
categories_set = set()
for categories in data["Category"].values:
    categories = str(categories)
    categories_set.add(categories.split(" | ")[0])
print(len(categories_set))
# Out:
# 20

# %%
data.head(1)
# Out:
#                             Uniq Id  \
# 0  4c69b61db1fc16e7013b43fc926e502d
#
#                                         Product Name  \
# 0  DB Longboards CoreFlex Crossbow 41" Bamboo Fib...
#
#                                             Category Upc Ean Code  \
# 0  Sports & Outdoors | Outdoor Recreation | Skate...          NaN
#
#   Selling Price Model Number  \
# 0       $237.68          NaN
#
#                                        About Product  \
# 0  Make sure this fits by entering your model num...
#
#                                Product Specification Technical Details  \
# 0  Shipping Weight: 10.7 pounds (View shipping ra...               NaN
#
#   Shipping Weight Product Dimensions  \
# 0     10.7 pounds                NaN
#
#                                                Image  \
# 0  https://images-na.ssl-images-amazon.com/images...
#
#                                             Variants  \
# 0  https://www.amazon.com/DB-Longboards-CoreFlex-...
#
# ...

# %%
import random

def processing(row):
    category = id_by_cate[str(row["Category"]).split(" | ")[0]]
    body = {
        "name" : str(row["Product Name"]),
        "description" : str(row["About Product"]),
        "status" : "PUBLIC",
        "category" : category,
        "price" : random.randint(2, 200),
        "quantity" : 100,
        "image" : str(row["Image"])
    }
    resp = requests.post(URL_CREATE_POST,
                        data = json.dumps(body),
                        headers = {
                            "Content-Type" : "application/json",
                            "Authorization" : "Bearer %s" % TOKEN
                        })
    print(resp)

# %%
categories_set = list(categories_set)

# %%
num_transactions = 1000
max_items_per_transaction = 5

# %%
import random

transactions = []
for _ in range(num_transactions):
    num_items = random.randint(1, max_items_per_transaction)
    transaction = random.sample(categories_set, num_items)
    transactions.append(transaction)

# Print the first few transactions to check
for t in transactions[99:120]:
    print(t)
# Out:
# ['Tools & Home Improvement', 'Pet Supplies', 'Clothing, Shoes & Jewelry', 'Health & Household', 'Baby Products']
# ['Video Games', 'Toys & Games', 'Tools & Home Improvement', 'Baby Products', 'Industrial & Scientific']
# ['Beauty & Personal Care', 'Health & Household']
# ['Health & Household', 'Industrial & Scientific', 'Tools & Home Improvement']
# ['Office Products', 'Remote & App Controlled Vehicle Parts', 'Video Games']
# ['Arts, Crafts & Sewing', 'Remote & App Controlled Vehicle Parts', 'Clothing, Shoes & Jewelry', 'Industrial & Scientific', 'Toys & Games']
# ['Remote & App Controlled Vehicle Parts']
# ['Toys & Games', 'Beauty & Personal Care', 'Baby Products']
# ['Health & Household', 'Remote & App Controlled Vehicles & Parts', 'Industrial & Scientific', 'Grocery & Gourmet Food', 'Hobbies']
# ['Toys & Games', 'Electronics', 'Automotive', 'Video Games']
# ['Industrial & Scientific', 'Patio, Lawn & Garden', 'Baby Products', 'Office Products', 'Automotive']
# ...

# %%
# %pip install mlxtend
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 4.6 MB/s eta 0:00:0000:0100:010m
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# Create a list of dictionaries where each dictionary represents a transaction
transaction_list = [{item: (item in t) for item in categories_set} for t in transactions]

# Convert the list of dictionaries to a DataFrame
df = pd.DataFrame(transaction_list).astype(int)

# Print the DataFrame to verify

from mlxtend.frequent_patterns import apriori, association_rules

# # Apply the apriori algorithm
frequent_itemsets = apriori(df, min_support=0.01, use_colnames=True)

# # Generate the association rules
rules = association_rules(frequent_itemsets, metric="lift", min_threshold=1)

# # Print the rules
print(rules.head()["antecedents"])
# Out:
# 0             (Office Products)
# 1              (Home & Kitchen)
# 2              (Home & Kitchen)
# 3    (Tools & Home Improvement)
# 4              (Home & Kitchen)
# Name: antecedents, dtype: object
# /opt/homebrew/Cellar/jupyterlab/4.1.6/libexec/lib/python3.12/site-packages/mlxtend/frequent_patterns/fpcommon.py:109: DeprecationWarning: DataFrames with non-bool types result in worse computationalperformance and their support might be discontinued in the future.Please use a DataFrame with bool type
#   warnings.warn(

# %%
data = pd.read_csv("transactions.csv", index_col=False)
data["Unnamed: 0"]
# Out:
# 0        0
# 1        1
# 2        2
# 3        3
# 4        4
#       ...
# 995    995
# 996    996
# 997    997
# 998    998
# 999    999
# Name: Unnamed: 0, Length: 1000, dtype: int64

# %%
rules
# Out:
#                      antecedents                 consequents  \
# 0              (Office Products)            (Home & Kitchen)
# 1               (Home & Kitchen)           (Office Products)
# 2               (Home & Kitchen)  (Tools & Home Improvement)
# 3     (Tools & Home Improvement)            (Home & Kitchen)
# 4               (Home & Kitchen)              (Pet Supplies)
# ..                           ...                         ...
# 131  (Clothing, Shoes & Jewelry)    (Grocery & Gourmet Food)
# 132                (Electronics)             (Baby Products)
# 133              (Baby Products)               (Electronics)
# 134     (Grocery & Gourmet Food)                   (Hobbies)
# 135                    (Hobbies)    (Grocery & Gourmet Food)
#
#      antecedent support  consequent support  support  confidence      lift  \
# 0                 0.156               0.164    0.026    0.166667  1.016260
# 1                 0.164               0.156    0.026    0.158537  1.016260
# ...

# %%
for x in rules[["antecedents", "consequents"]].iterrows():
    print(set(x[1][0]), set(x[1][1]))
# Out:
# {'Office Products'} {'Home & Kitchen'}
# {'Home & Kitchen'} {'Office Products'}
# {'Home & Kitchen'} {'Tools & Home Improvement'}
# {'Tools & Home Improvement'} {'Home & Kitchen'}
# {'Home & Kitchen'} {'Pet Supplies'}
# {'Pet Supplies'} {'Home & Kitchen'}
# {'Home & Kitchen'} {'Remote & App Controlled Vehicles & Parts'}
# {'Remote & App Controlled Vehicles & Parts'} {'Home & Kitchen'}
# {'Home & Kitchen'} {'Industrial & Scientific'}
# {'Industrial & Scientific'} {'Home & Kitchen'}
# {'Home & Kitchen'} {'Hobbies'}
# {'Hobbies'} {'Home & Kitchen'}
# {'Home & Kitchen'} {'Electronics'}
# {'Electronics'} {'Home & Kitchen'}
# {'Office Products'} {'Toys & Games'}
# {'Toys & Games'} {'Office Products'}
# {'Sports & Outdoors'} {'Toys & Games'}
# {'Toys & Games'} {'Sports & Outdoors'}
# {'Remote & App Controlled Vehicle Parts'} {'Toys & Games'}
# {'Toys & Games'} {'Remote & App Controlled Vehicle Parts'}
# {'Patio, Lawn & Garden'} {'Toys & Games'}
# {'Toys & Games'} {'Patio, Lawn & Garden'}
# ...
